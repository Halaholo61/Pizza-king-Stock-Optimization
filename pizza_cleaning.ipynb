# %%
import pandas as pd

# %%
DF_Address = pd.read_csv('address_data.csv')

# %%
DF_Address
# Out:
#      add_id   delivery_address1 delivery_address2 delivery_city  \
# 0         1      12 Main Street            Apt 4B  Summit Peaks
# 1         2      456 Oak Avenue         Suite 205    Ravencrest
# 2         3      245 Maple Lane               NaN    Ravencrest
# 3         4  101 Pine Boulevard               NaN    Ravencrest
# 4         5       218 Elm Court               NaN    Ravencrest
# ..      ...                 ...               ...           ...
# 108     109   209 Elm Boulevard               NaN    Ravencrest
# 109     110    261 Willow Drive               NaN    Ravencrest
# 110     111  143 Juniper Circle            Apt 9G      Azureton
# 111     112    46 Magnolia Road               NaN      Azureton
# 112     113    70 Spruce Avenue               NaN    Ravencrest
#
#     delivery_postcode
# 0             Z1A 2B8
# 1             V3C 4D5
# 2             V4D 0Y8
# 3             V6P 8R4
# 4             V1U 1J5
# ..                ...
# 108           V1U 7I2
# ...

# %%
DF_Address.shape
# Out:
# (113, 5)

# %%
DF_Address.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113 entries, 0 to 112
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   add_id             113 non-null    int64
#  1   delivery_address1  113 non-null    object
#  2   delivery_address2  34 non-null     object
#  3   delivery_city      113 non-null    object
#  4   delivery_postcode  113 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.5+ KB

# %%
DF_Address.isna().sum()
# Out:
# add_id                0
# delivery_address1     0
# delivery_address2    79
# delivery_city         0
# delivery_postcode     0
# dtype: int64

# %%
DF_Address.to_csv ('c_address.csv', index=False)

# %%
DF_Customers = pd.read_csv('customers_data.csv')

# %%
DF_Customers
# Out:
#      cust_id cust_firstname cust_lastname  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0        1.0          Laura        Taylor         NaN         NaN         NaN
# 1        2.0           Mark      Anderson         NaN         NaN         NaN
# 2        3.0           John         Smith         NaN         NaN         NaN
# 3        4.0          Emily       Johnson         NaN         NaN         NaN
# 4        5.0        Michael         Davis         NaN         NaN         NaN
# ..       ...            ...           ...         ...         ...         ...
# 134      NaN            NaN           NaN         NaN         NaN         NaN
# 135      NaN            NaN           NaN         NaN         NaN         NaN
# 136      NaN            NaN           NaN         NaN         NaN         NaN
# 137      NaN            NaN           NaN         NaN         NaN         NaN
# 138      NaN            NaN           NaN         NaN         NaN         NaN
#
#      Unnamed: 6  Unnamed: 7
# ...

# %%
DF_Customers.shape
# Out:
# (139, 8)

# %%
DF_Customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139 entries, 0 to 138
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   cust_id         117 non-null    float64
#  1   cust_firstname  117 non-null    object
#  2   cust_lastname   117 non-null    object
#  3   Unnamed: 3      0 non-null      float64
#  4   Unnamed: 4      0 non-null      float64
#  5   Unnamed: 5      0 non-null      float64
#  6   Unnamed: 6      0 non-null      float64
#  7   Unnamed: 7      0 non-null      float64
# dtypes: float64(6), object(2)
# memory usage: 8.8+ KB

# %%
DF_Customers.isna().sum()
# Out:
# cust_id            22
# cust_firstname     22
# cust_lastname      22
# Unnamed: 3        139
# Unnamed: 4        139
# Unnamed: 5        139
# Unnamed: 6        139
# Unnamed: 7        139
# dtype: int64

# %%
DF_Customers = DF_Customers.dropna(axis=1, how='all')

# %%
DF_Customers = DF_Customers.dropna()

# %%
DF_Customers.isna().sum()
# Out:
# cust_id           0
# cust_firstname    0
# cust_lastname     0
# dtype: int64

# %%
DF_Customers['cust_id'] = DF_Customers['cust_id'].astype(int)

# %%
DF_Customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 117 entries, 0 to 116
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   cust_id         117 non-null    int32
#  1   cust_firstname  117 non-null    object
#  2   cust_lastname   117 non-null    object
# dtypes: int32(1), object(2)
# memory usage: 3.2+ KB

# %%
DF_Customers.to_csv ('c_customers.csv', index=False)

# %%
DF_Ingredients = pd.read_csv('ingredients_data.csv')

# %%
DF_Ingredients
# Out:
#     ing_id                    ing_name  ing_weight ing_meas  ing_price
# 0   ing001  Pizza dough ball  (8 pack)        2000    grams       4.59
# 1   ing002                Tomato sauce        4500    grams       3.89
# 2   ing003                Donair sauce        4500    grams       4.99
# 3   ing004                 Ranch sauce        4500    grams       4.99
# 4   ing005                  Mozzarella        2500    grams      14.45
# 5   ing006                   Pepperoni        2500    grams      23.22
# 6   ing007                         Ham        5000    grams      32.45
# 7   ing008                   Pineapple        5000    grams       6.43
# 8   ing009                 Donair meat        5000    grams      35.72
# 9   ing010                       Onion        1000    grams       4.97
# 10  ing011                    Tomatoes        1000    grams       3.78
# 11  ing012                     Chicken        5000    grams      31.25
# ...

# %%
DF_Ingredients.shape
# Out:
# (23, 5)

# %%
DF_Ingredients.isna().sum()
# Out:
# ing_id        0
# ing_name      0
# ing_weight    0
# ing_meas      0
# ing_price     0
# dtype: int64

# %%
DF_Ingredients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ing_id      23 non-null     object
#  1   ing_name    23 non-null     object
#  2   ing_weight  23 non-null     int64
#  3   ing_meas    23 non-null     object
#  4   ing_price   23 non-null     float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 1.0+ KB

# %%
DF_Ingredients.to_csv('c_ingredients.csv', index=False)

# %%
DF_Inventory = pd.read_csv('inventory_data.csv')

# %%
DF_Inventory.shape
# Out:
# (23, 3)

# %%
DF_Inventory
# Out:
#     inv_id item_id  quantity
# 0   inv001  ing001        20
# 1   inv002  ing002         5
# 2   inv003  ing003         4
# 3   inv004  ing004         4
# 4   inv005  ing005         6
# 5   inv006  ing006         4
# 6   inv007  ing007         3
# 7   inv008  ing008         3
# 8   inv009  ing009         2
# 9   inv010  ing010        20
# 10  inv011  ing011        15
# 11  inv012  ing012         2
# 12  inv013  ing013         2
# 13  inv014  ing014         5
# 14  inv015  ing015         1
# 15  inv016  ing016        10
# 16  inv017  ing017         1
# 17  inv018  ing018         2
# 18  inv019  ing019         2
# 19  inv020  ing020         2
# 20  inv021  ing021         2
# 21  inv022  ing022         4
# 22  inv023  ing023         1

# %%
DF_Inventory.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   inv_id    23 non-null     object
#  1   item_id   23 non-null     object
#  2   quantity  23 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 684.0+ bytes

# %%
DF_Inventory.isna().sum()
# Out:
# inv_id      0
# item_id     0
# quantity    0
# dtype: int64

# %%
DF_Inventory.to_csv('c_inventory.csv', index=False)

# %%
DF_Item = pd.read_csv('item_data.csv')

# %%
DF_Item.shape
# Out:
# (30, 6)

# %%
DF_Item
# Out:
#    item_id          sku            item_name  item_cat item_size  item_price
# 0    it001  PIZZ-CHEE-S               Cheese     Pizza     Small       19.99
# 1    it002  PIZZ-CHEE-M               Cheese     Pizza    Medium       24.99
# 2    it003  PIZZ-CHEE-L               Cheese     Pizza     Large       29.99
# 3    it004  PIZZ-PEPP-S            Pepperoni     Pizza     Small       20.99
# 4    it005  PIZZ-PEPP-M            Pepperoni     Pizza    Medium       25.99
# 5    it006  PIZZ-PEPP-L            Pepperoni     Pizza     Large       31.99
# 6    it007  PIZZ-HAWA-S             Hawaiian     Pizza     Small       21.99
# 7    it008  PIZZ-HAWA-M             Hawaiian     Pizza    Medium       26.99
# 8    it009  PIZZ-HAWA-L             Hawaiian     Pizza     Large       32.99
# 9    it010  PIZZ-DONA-S               Donair     Pizza     Small       23.99
# 10   it011  PIZZ-DONA-M               Donair     Pizza    Medium       29.99
# ...

# %%
DF_Item.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   item_id     30 non-null     object
#  1   sku         30 non-null     object
#  2   item_name   30 non-null     object
#  3   item_cat    30 non-null     object
#  4   item_size   30 non-null     object
#  5   item_price  30 non-null     float64
# dtypes: float64(1), object(5)
# memory usage: 1.5+ KB

# %%
DF_Item.isna().sum()
# Out:
# item_id       0
# sku           0
# item_name     0
# item_cat      0
# item_size     0
# item_price    0
# dtype: int64

# %%
DF_Item.to_csv('c_item.csv', index=False)

# %%
DF_Orders =pd.read_csv('orders_data.csv')

# %%
DF_Orders.shape
# Out:
# (479, 9)

# %%
DF_Orders
# Out:
#      row_id  order_id        created_at item_id  quantity  cust_id  delivery  \
# 0         1       101  2024-01-13 12:15   it018         1        1         1
# 1         2       101  2024-01-13 12:15   it021         2        1         1
# 2         3       102  2024-01-13 13:00   it027         4        2         1
# 3         4       102  2024-01-13 13:00   it028         1        2         1
# 4         5       103  2024-01-13 18:30   it002         1        3         1
# ..      ...       ...               ...     ...       ...      ...       ...
# 474     475       283  2024-02-09 18:30   it006         1       42         1
# 475     476       283  2024-02-09 18:30   it019         1       42         1
# 476     477       284  2024-02-09 20:45   it010         1      117         1
# 477     478       285  2024-02-09 22:00   it005         1       73         0
# 478     479       285  2024-02-09 22:00   it013         1       73         0
#
#      add_id  Unnamed: 8
# ...

# %%
DF_Orders.isna().sum()
# Out:
# row_id          0
# order_id        0
# created_at      0
# item_id         0
# quantity        0
# cust_id         0
# delivery        0
# add_id          0
# Unnamed: 8    479
# dtype: int64

# %%
DF_Orders = DF_Orders.dropna(axis=1, how='all')

# %%
DF_Orders.to_csv('c_orders.csv', index=False)

# %%
DF_Recipe = pd.read_csv('recipe_data.csv')

# %%
DF_Recipe.shape
# Out:
# (99, 4)

# %%
DF_Recipe
# Out:
#     row_id    recipe_id  ing_id  quantity
# 0        1  PIZZ-CHEE-S  ing001       200
# 1        2  PIZZ-CHEE-S  ing002        60
# 2        3  PIZZ-CHEE-S  ing005       140
# 3        4  PIZZ-CHEE-M  ing001       250
# 4        5  PIZZ-CHEE-M  ing002        80
# ..     ...          ...     ...       ...
# 94      95  SIDE-CAES-R  ing018        10
# 95      96  SIDE-CAES-R  ing019         5
# 96      97  SIDE-CAES-R  ing023        10
# 97      98  DESS-CHBR-R  ing020       150
# 98      99  DESS-CHCA-R  ing021       150
#
# [99 rows x 4 columns]

# %%
DF_Recipe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   row_id     99 non-null     int64
#  1   recipe_id  99 non-null     object
#  2   ing_id     99 non-null     object
#  3   quantity   99 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 3.2+ KB

# %%
DF_Recipe.isna().sum()
# Out:
# row_id       0
# recipe_id    0
# ing_id       0
# quantity     0
# dtype: int64

# %%
DF_Recipe.to_csv('c_recipe.csv', index=False)

# %%
DF_Rota = pd.read_csv('rota_data.csv')

# %%
DF_Rota.shape
# Out:
# (224, 5)

# %%
DF_Rota
# Out:
#      row_id rota_id        date shift_id staff_id
# 0         1  ro0001  2024-01-13   sh0011   st0001
# 1         2  ro0001  2024-01-13   sh0011   st0002
# 2         3  ro0001  2024-01-13   sh0011   st0009
# 3         4  ro0001  2024-01-13   sh0011   st0010
# 4         5  ro0001  2024-01-13   sh0012   st0003
# ..      ...     ...         ...      ...      ...
# 219     220  ro0028  2024-02-09   sh0009   st0014
# 220     221  ro0028  2024-02-09   sh0010   st0007
# 221     222  ro0028  2024-02-09   sh0010   st0008
# 222     223  ro0028  2024-02-09   sh0010   st0015
# 223     224  ro0028  2024-02-09   sh0010   st0016
#
# [224 rows x 5 columns]

# %%
DF_Rota.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 224 entries, 0 to 223
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   row_id    224 non-null    int64
#  1   rota_id   224 non-null    object
#  2   date      224 non-null    object
#  3   shift_id  224 non-null    object
#  4   staff_id  224 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 8.9+ KB

# %%
DF_Rota['date'] = pd.to_datetime(DF_Rota['date'])

# %%
DF_Rota.isna().sum()
# Out:
# row_id      0
# rota_id     0
# date        0
# shift_id    0
# staff_id    0
# dtype: int64

# %%
DF_Rota.to_csv('c_rota.csv', index=False)

# %%
DF_Shift=pd.read_csv('shift_data.csv')

# %%
DF_Shift.shape
# Out:
# (14, 4)

# %%
DF_Shift
# Out:
#    shift_id day_of_week start_time  end_time
# 0    sh0001      Monday   10:30:00  17:00:00
# 1    sh0002      Monday   17:00:00  23:30:00
# 2    sh0003     Tuesday   10:30:00  17:00:00
# 3    sh0004     Tuesday   17:00:00  23:30:00
# 4    sh0005   Wednesday   10:30:00  17:00:00
# 5    sh0006   Wednesday   17:00:00  23:30:00
# 6    sh0007    Thursday   10:30:00  17:00:00
# 7    sh0008    Thursday   17:00:00  23:30:00
# 8    sh0009      Friday   10:30:00  17:00:00
# 9    sh0010      Friday   17:00:00  23:30:00
# 10   sh0011    Saturday   10:30:00  17:00:00
# 11   sh0012    Saturday   17:00:00  23:30:00
# 12   sh0013      Sunday   10:30:00  17:00:00
# 13   sh0014      Sunday   17:00:00  23:30:00

# %%
DF_Shift.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   shift_id     14 non-null     object
#  1   day_of_week  14 non-null     object
#  2   start_time   14 non-null     object
#  3   end_time     14 non-null     object
# dtypes: object(4)
# memory usage: 580.0+ bytes

# %%
DF_Shift.isna().sum()
# Out:
# shift_id       0
# day_of_week    0
# start_time     0
# end_time       0
# dtype: int64

# %%
DF_Shift.to_csv('c_shift.csv', index=False)

# %%
DF_Staff=pd.read_csv('staff_data.csv')

# %%
DF_Staff.shape
# Out:
# (16, 5)

# %%
DF_Staff
# Out:
#    staff_id first_name last_name         position  hourly_rate
# 0    st0001       Liam  Anderson        Prep chef        16.50
# 1    st0002     Olivia   Johnson             Chef        21.25
# 2    st0003      Ethan     Smith        Prep chef        16.50
# 3    st0004        Ava     Brown             Chef        21.25
# 4    st0005       Noah     Davis        Prep chef        16.50
# 5    st0006       Emma    Taylor             Chef        21.25
# 6    st0007      Mason    Miller        Prep chef        16.50
# 7    st0008     Sophia    Wilson             Chef        21.25
# 8    st0009      Logan     Moore  Delivery driver        15.00
# 9    st0010   Isabella  Martinez  Delivery driver        15.00
# 10   st0011      Aiden   Jackson  Delivery driver        15.00
# 11   st0012        Mia     White  Delivery driver        15.00
# 12   st0013      Lucas    Harris  Delivery driver        15.00
# 13   st0014     Amelia    Nelson  Delivery driver        15.00
# ...

# %%
DF_Staff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   staff_id     16 non-null     object
#  1   first_name   16 non-null     object
#  2   last_name    16 non-null     object
#  3   position     16 non-null     object
#  4   hourly_rate  16 non-null     float64
# dtypes: float64(1), object(4)
# memory usage: 772.0+ bytes

# %%
DF_Staff.isna().sum()
# Out:
# staff_id       0
# first_name     0
# last_name      0
# position       0
# hourly_rate    0
# dtype: int64

# %%
DF_Staff.to_csv('c_staff.csv', index=False)
